# %%
from coil_fem.simsopt import CoilSupportBeamsSorted
from coil_fem.simsopt import CoilFEMObjective
import gmsh
from simsopt.configs import get_data
from simsopt.mhd import Vmec
from simsopt import save, load
import numpy as np
import jax
import time
from simsopt.field import Coil
# Out:
#        __       ___      ___   ___                _______  _______ .___  ___.
#       |  |     /   \     \  \ /  /               |   ____||   ____||   \/   |
#       |  |    /  ^  \     \  V  /      ______    |  |__   |  |__   |  \  /  |
# .--.  |  |   /  /_\  \     >   <      |______|   |   __|  |   __|  |  |\/|  |
# |  `--'  |  /  _____  \   /  .  \                |  |     |  |____ |  |  |  |
#  \______/  /__/     \__\ /__/ \__\               |__|     |_______||__|  |__|

# %% [markdown]
# ## Defining `coil-fem` penalty

# %% [markdown]
# ### Defining the simsopt objective
# We now defined the simsopt objective for `coil-fem`. The `CoilFEMObjective`
# simsopt `Optimizable` handles all forward solves and gradient calculations.
# Each `CoilFEMObjective` maintains its own FEM problem.
#
# The mesh density is controlled by the centerlines `quadpoints` counts.
# the number of cells in the cross section is automatically calculated to
# produce mesh cells so that each cell's aspect ratio is roughly
# `mesh_options['aspect_ratio']`.
#
# **Note:** When multiple `coil-fem` penalties are needed, please initialize one
# `CoilFEMObjective` instance with a list of `metrics` and `metric_weights`
# instead of defining multiple `CoilFEMObjective` instances. This way, `coil-fem`
# can compute all metrics and gradients in one FEM pass. Creating multiple
# `CoilFEMObjective` instances for the same problem will cause `coil-fem` to repeat
# the same FEM computation. This will cause unnecessary memory and time usage.

# %%
import json
from pathlib import Path

_OPTIONS_PATH = Path('..') / 'cfqs-options.json'
opts = json.load(open(_OPTIONS_PATH))
mesh_options = opts['mesh_options']
material_options = opts['material_options']
gravity_options = opts['gravity_options']
problem_options = opts['problem_options']
physics_options = opts['physics_options']
beam_options = opts['beam_options']
fixed_clamp_options = opts['fixed_clamp_options']

# %%
mesh_scale = 0.5

# %%
# The Simsopt wrapper for a differentiable FEM problem.
# It behaves like a simsopt objective.
Jstress = load('init_Jstress_auglag.json')[0]
print(Jstress)
# Out:
# /home/lf2869/Documents/Codes/coil-fem/src/coil_fem/simsopt/coil_support_beams.py:323: UserWarning: Unrecognized keys in beam_options: ['comment'].
#   warnings.warn(
# Beam network initialized.
# Optimizing:
#     dphis_end_cc - per-coil shapes: [(4,), (4,), (4,), (2,), (2,)]
#     dphis_start_cc - per-coil shapes: [(4,), (4,), (4,), (2,), (2,)]
#     thetas_orientation_cc - per-coil shapes: [(4,), (4,), (4,), (2,), (2,)]
#     phis_start_cs - per-coil shapes: (2,)
#     phis_end_cs - per-coil shapes: (2,)
#     thetas_orientation_cs - per-coil shapes: (2,)
# Fixing:
#     r_beam
#     dphis_start_cf
#     x_foundation
#     thetas_orientation_cf
# Total # dofs: 54
# /home/lf2869/Documents/Codes/coil-fem/src/coil_fem/coupling/drivers.py:410: RuntimeWarning: Your FEM solve may be using only 25% of available VRAM! problem_options['solver']='cudss', but XLA_PYTHON_CLIENT_PREALLOCATE is None. XLA preallocates 75% of the device by default; cuDSS allocates its factorisation *outside* XLA's pool and cannot borrow from it, so the GPU utilization may be inefficient if you are not using other jax/XLA codes. Set XLA_PYTHON_CLIENT_PREALLOCATE=false and XLA_PYTHON_CLIENT_MEM_FRACTION=0.5 in your job script, or call coil_fem.gpu_env.configure_gpu_memory() before importing coil_fem and jax.
#   CuDSSSolver = _import_cudss_solver()
# CoilFEMObjective1

# %%
coil_support = Jstress.coil_support
support   = Jstress.fem.support         # the SupportBeams instance
sdofs     = coil_support.support_dofs      # dict pytree
curves = Jstress.fem.base_curves_jax
# base_dofs = [c.dofs for c in fem.base_curves_jax]
# curves = [CurveXYZFourierJAX(c.quadpoints, base_dofs[i], c.order)
#           for i, c in enumerate(fem.base_curves_jax)]
geom = support.beam_geometry(curves, sdofs)     # note: private, but stable
x_start = np.asarray(geom['x_start'])            # (N_beams, 3)
x_end   = np.asarray(geom['x_end'])              # (N_beams, 3)
gamma3  = np.asarray(geom['gamma3'])  # (N,3,3)

# %%
# Pulling beam radii
A_all, Iy, Iz, J = support.cross_section_fn(sdofs)
A = np.concatenate([np.atleast_1d(np.asarray(a)) for a in A_all])  # (N_beams,)
radii = np.sqrt(A / np.pi)          # area-equivalent radius; for solid_circle this == r_beam

# %%
import gmsh
gmsh.initialize()
gmsh.model.add("device")
occ = gmsh.model.occ
solids = []
# --- beams: cylinders ---
for xs, xe, r in zip(x_start, x_end, radii):
    d = xe - xs
    tag = occ.addCylinder(xs[0], xs[1], xs[2], d[0], d[1], d[2], float(r))
    solids.append((3, tag))

# %% [markdown]
# ### Step 2: coil solids
# Each coil is lofted from its true FEM cross-section (the $w_1 \times w_2$ rectangle carried on the rotation-minimizing frame), sampled as ring wires along the centerline — the same geometry `coil-fem` sweeps into TET meshes. A closed loop cannot be lofted in one OCC pass, so each coil is two half lofts that the boolean fuse glues back together. Each base coil is then replicated over **every field period and stellarator-symmetry image** (rotate by $2\pi k/n_{fp}$ about $z$, then flip $\mathrm{diag}(1,-1,-1)$ when reflecting — the same convention as `coil_fem.geo.symmetries.apply_symmetries_to_gammas`), reconstructing the complete physical coilset rather than just the pair of images touched by wraparound beams.

# %%
# ============================================================================
# Step 2: coils as OCC solids (lofted rectangular sweeps + symmetry images)
# ============================================================================
# Each coil solid is built by lofting its *true* FEM cross-section — the
# w1 x w2 rectangle in the RMF frame, exactly as _rect_sweep_points sweeps it:
#     x = gamma(phi) + (w1/2) u p(phi) + (w2/2) v q(phi)
# OCC cannot loft a closed loop in a single pass, so each coil is built as
# two half lofts; the boolean fuse in Step 3 glues them into one volume.
#
# Every base coil is then replicated over all nfp field periods and (when
# stellsym) the stellarator-reflection image, reconstructing the full
# physical coilset (see the symmetry-image block below).

meshes = Jstress.fem.meshes          # FramedCurveMeshRectangle, one per base coil

def add_coil_solid(mesh, n_slices=96):
    """Loft one coil into two half solids; returns their (dim, tag) list."""
    fc  = mesh.framed_curve
    phi = np.linspace(0.0, 1.0, n_slices, endpoint=False)
    r0  = np.asarray(fc.curve.gamma_eval(phi))       # (K, 3) centerline
    _, p, q = fc.rotated_frame_eval(phi)             # cross-section frame
    p, q = np.asarray(p), np.asarray(q)

    # Same corner convention as the FEM sweep; consistent CCW ordering of the
    # ring wires guarantees the loft does not twist between sections.
    corners = [(-1., -1.), (1., -1.), (1., 1.), (-1., 1.)]
    wires = []
    for k in range(n_slices):
        pts = [
            occ.addPoint(*(r0[k] + 0.5 * mesh.w1 * u * p[k]
                                 + 0.5 * mesh.w2 * v * q[k]))
            for (u, v) in corners
        ]
        lines = [occ.addLine(pts[a], pts[(a + 1) % 4]) for a in range(4)]
        wires.append(occ.addWire(lines))

    # makeRuled=True: straight facets between rings — matches the linear
    # phi-sweep of the FEM mesh and is robust (no B-spline self-intersection).
    half = n_slices // 2
    out  = []
    out += occ.addThruSections(wires[:half + 1], makeSolid=True, makeRuled=False)
    out += occ.addThruSections(wires[half:] + [wires[0]],
                               makeSolid=True, makeRuled=False)
    occ.remove([(1, w) for w in wires], recursive=True)  # construction wires
    return out

coil_solids = [add_coil_solid(m) for m in meshes]

# %% [markdown]
# ### Step 3: fuse, reflect and mesh
# All beam cylinders (including the wraparound/bridge groups) are fused together with the sector's coils into one per-sector unit, which is then rigidly reflected over every field-period rotation and (when stellsym) the stellarator-reflection image. Each master/partner beam pair is designed so its reflected copies land at distinct physical locations — no de-duplication needed.
# All beam cylinders, coil half-lofts, and image coils are fused into a single solid — the beam endpoints sit on the coil centerlines, so every cylinder overlaps its coils and the union is watertight and conforming. The fused body is then tet-meshed; mesh size is bounded by the smallest beam radius and the coil width, and `MeshSizeFromCurvature` keeps the cylinder walls round.

# %%
# ============================================================================
# Step 3: boolean fuse into one solid + tetrahedral meshing
# ============================================================================
# The beam endpoints lie on the coil *centerlines*, so every cylinder is
# embedded in its two coils and the fuse produces a single conforming volume
# (internal faces — including the half-loft seams — are dissolved).

fused_solid_1fp = solids + [dt for cs in coil_solids for dt in cs]
fused_1fp, _ = occ.fuse(fused_solid_1fp[:1], fused_solid_1fp[1:])
occ.synchronize()

# Reflect the whole per-sector unit (coils + all beams, wraparound/bridge
# groups included) over all nfp field periods and (when stellsym) the
# stellarator-reflection image. Convention mirrors coil_fem.geo.symmetries
# (apply_symmetries_to_gammas): rotate phi = 2*pi*k/nfp about z, then flip
# diag(1, -1, -1) when reflecting; (k=0, flip=False) is fused_1fp itself.
nfp, stellsym = support.nfp, support.stellsym
flip_list = (False, True) if stellsym else (False,)
flip_Q = np.diag([1.0, -1.0, -1.0])

image_solids = []
for k in range(nfp):
    phi = 2.0 * np.pi * k / nfp
    c, s = np.cos(phi), np.sin(phi)
    rot_Q = np.array([[c, -s, 0.0], [s, c, 0.0], [0.0, 0.0, 1.0]])
    for flip in flip_list:
        if k == 0 and not flip:
            continue  # identity: already in fused_1fp
        Q = (flip_Q @ rot_Q) if flip else rot_Q   # rotate, then flip
        affine = list(np.hstack([Q, np.zeros((3, 1))]).ravel())
        copies = occ.copy(fused_1fp)
        occ.affineTransform(copies, affine)
        image_solids += copies

n_images = nfp * len(flip_list) - 1
print(f'{len(solids)} beam cylinders, '
      f'{sum(len(c) for c in coil_solids)} base-coil half-lofts, '
      f'{len(image_solids)} image half-lofts '
      f'({n_images} field-period/symmetry images x {len(coil_solids)} base coils)')
# Out:
# 18 beam cylinders, 8 base-coil half-lofts, 3 image half-lofts (3 field-period/symmetry images x 4 base coils)

# %%
# fused_1fp is itself a list of (dim, tag) pairs (occ.fuse's output), so it
# must be *concatenated* with the other lists, not nested inside another list
# (nesting is what produced the "Invalid data for input vector of pairs"
# error -- gmsh expects one flat list of (dim, tag) tuples).
fused_solid_all = fused_1fp + image_solids
fused_all, _ = occ.fuse(fused_solid_all[:1], fused_solid_all[1:])
occ.synchronize()

# %%
vols = gmsh.model.getEntities(3)
print(f'{len(vols)} volume(s) after fuse')   # >1 means a part is not touching
gmsh.model.addPhysicalGroup(3, [t for _, t in vols], name='device')

# Mesh sizing: resolve the beam radii and the coil cross-section.
r_min = float(radii.min())
gmsh.option.setNumber('Mesh.MeshSizeMax', mesh_scale * 0.5 * mesh_options['w1'])
gmsh.option.setNumber('Mesh.MeshSizeMin', mesh_scale * 0.15 * r_min)
gmsh.option.setNumber('Mesh.MeshSizeFromCurvature', 12)  # pts per 2*pi
gmsh.option.setNumber('Mesh.ElementOrder', 2)  # TET10

t0 = time.time()
gmsh.model.mesh.generate(3)
print(f'meshed in {time.time() - t0:.1f} s')
# Out:
# 1 volume(s) after fuse
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 151 (Line)
# Info    : [ 10%] Meshing curve 152 (Line)
# Info    : [ 10%] Meshing curve 153 (Line)
# Info    : [ 10%] Meshing curve 154 (Line)
# Info    : [ 10%] Meshing curve 155 (Line)
# Info    : [ 10%] Meshing curve 156 (Line)
# Info    : [ 10%] Meshing curve 157 (Line)
# Info    : [ 10%] Meshing curve 158 (Line)
# Info    : [ 10%] Meshing curve 159 (Line)
# Info    : [ 10%] Meshing curve 160 (Line)
# Info    : [ 10%] Meshing curve 161 (Line)
# Info    : [ 10%] Meshing curve 162 (Line)
# Info    : [ 10%] Meshing curve 259 (Line)
# Info    : [ 10%] Meshing curve 260 (Line)
# Info    : [ 10%] Meshing curve 261 (Line)
# Info    : [ 10%] Meshing curve 262 (Line)
# Info    : [ 10%] Meshing curve 263 (Line)
# Info    : [ 10%] Meshing curve 264 (Line)
# Info    : [ 10%] Meshing curve 265 (Line)
# Info    : [ 10%] Meshing curve 266 (Line)
# Info    : [ 10%] Meshing curve 267 (Line)
# Info    : [ 10%] Meshing curve 268 (Line)
# Info    : [ 10%] Meshing curve 269 (Line)
# Info    : [ 10%] Meshing curve 270 (Line)
# Info    : [ 10%] Meshing curve 367 (Line)
# Info    : [ 10%] Meshing curve 368 (Line)
# Info    : [ 10%] Meshing curve 369 (Line)
# Info    : [ 10%] Meshing curve 370 (Line)
# Info    : [ 10%] Meshing curve 371 (Line)
# Info    : [ 10%] Meshing curve 372 (Line)
# Info    : [ 10%] Meshing curve 373 (Line)
# Info    : [ 10%] Meshing curve 374 (Line)
# Info    : [ 10%] Meshing curve 375 (Line)
# Info    : [ 10%] Meshing curve 376 (Line)
# Info    : [ 10%] Meshing curve 377 (Line)
# Info    : [ 10%] Meshing curve 378 (Line)
# Info    : [ 10%] Meshing curve 475 (Line)
# Info    : [ 10%] Meshing curve 476 (Line)
# Info    : [ 10%] Meshing curve 477 (Line)
# Info    : [ 10%] Meshing curve 478 (Line)
# Info    : [ 10%] Meshing curve 479 (Line)
# Info    : [ 10%] Meshing curve 480 (Line)
# Info    : [ 10%] Meshing curve 481 (Line)
# Info    : [ 10%] Meshing curve 482 (Line)
# Info    : [ 10%] Meshing curve 483 (Line)
# Info    : [ 10%] Meshing curve 484 (Line)
# Info    : [ 10%] Meshing curve 610 (Line)
# Info    : [ 10%] Meshing curve 611 (Line)
# Info    : [ 10%] Meshing curve 612 (Line)
# Info    : [ 10%] Meshing curve 613 (Line)
# Info    : [ 10%] Meshing curve 614 (Line)
# Info    : [ 10%] Meshing curve 615 (Line)
# Info    : [ 10%] Meshing curve 616 (Line)
# Info    : [ 10%] Meshing curve 617 (Line)
# Info    : [ 10%] Meshing curve 618 (Line)
# Info    : [ 10%] Meshing curve 619 (Line)
# Info    : [ 10%] Meshing curve 620 (Line)
# Info    : [ 10%] Meshing curve 621 (Line)
# Info    : [ 10%] Meshing curve 622 (Line)
# Info    : [ 10%] Meshing curve 623 (Line)
# Info    : [ 10%] Meshing curve 624 (Line)
# Info    : [ 10%] Meshing curve 625 (Line)
# Info    : [ 10%] Meshing curve 626 (Line)
# Info    : [ 10%] Meshing curve 627 (Line)
# Info    : [ 10%] Meshing curve 628 (Line)
# Info    : [ 10%] Meshing curve 629 (Line)
# Info    : [ 10%] Meshing curve 630 (Line)
# Info    : [ 10%] Meshing curve 631 (Line)
# Info    : [ 10%] Meshing curve 632 (Line)
# Info    : [ 10%] Meshing curve 633 (Line)
# Info    : [ 10%] Meshing curve 634 (Line)
# Info    : [ 10%] Meshing curve 635 (Line)
# Info    : [ 10%] Meshing curve 636 (Line)
# Info    : [ 10%] Meshing curve 637 (Line)
# Info    : [ 10%] Meshing curve 638 (Line)
# Info    : [ 10%] Meshing curve 639 (Line)
# Info    : [ 10%] Meshing curve 640 (Line)
# Info    : [ 20%] Meshing curve 641 (Line)
# Info    : [ 20%] Meshing curve 642 (Line)
# Info    : [ 20%] Meshing curve 643 (Line)
# Info    : [ 20%] Meshing curve 644 (Line)
# Info    : [ 20%] Meshing curve 645 (Line)
# Info    : [ 20%] Meshing curve 646 (Line)
# Info    : [ 20%] Meshing curve 647 (Line)
# Info    : [ 20%] Meshing curve 648 (Line)
# Info    : [ 20%] Meshing curve 649 (Line)
# Info    : [ 20%] Meshing curve 650 (Line)
# Info    : [ 20%] Meshing curve 651 (Line)
# Info    : [ 20%] Meshing curve 652 (Line)
# Info    : [ 20%] Meshing curve 653 (Line)
# Info    : [ 20%] Meshing curve 654 (Line)
# Info    : [ 20%] Meshing curve 655 (Line)
# Info    : [ 20%] Meshing curve 656 (Line)
# Info    : [ 20%] Meshing curve 657 (Line)
# Info    : [ 20%] Meshing curve 658 (Line)
# Info    : [ 20%] Meshing curve 659 (Line)
# Info    : [ 20%] Meshing curve 660 (Line)
# Info    : [ 20%] Meshing curve 661 (Line)
# Info    : [ 20%] Meshing curve 662 (Line)
# Info    : [ 20%] Meshing curve 663 (Line)
# Info    : [ 20%] Meshing curve 664 (Line)
# Info    : [ 20%] Meshing curve 665 (Line)
# Info    : [ 20%] Meshing curve 666 (Line)
# Info    : [ 20%] Meshing curve 667 (Line)
# Info    : [ 20%] Meshing curve 668 (Line)
# Info    : [ 20%] Meshing curve 669 (Line)
# Info    : [ 20%] Meshing curve 670 (Line)
# Info    : [ 20%] Meshing curve 671 (Line)
# Info    : [ 20%] Meshing curve 672 (Line)
# Info    : [ 20%] Meshing curve 673 (Line)
# Info    : [ 20%] Meshing curve 674 (Line)
# Info    : [ 20%] Meshing curve 675 (Line)
# Info    : [ 20%] Meshing curve 676 (Line)
# Info    : [ 20%] Meshing curve 677 (Line)
# Info    : [ 20%] Meshing curve 678 (Line)
# Info    : [ 20%] Meshing curve 679 (Line)
# Info    : [ 20%] Meshing curve 680 (Line)
# Info    : [ 20%] Meshing curve 681 (Line)
# Info    : [ 20%] Meshing curve 682 (Line)
# Info    : [ 20%] Meshing curve 683 (Line)
# Info    : [ 20%] Meshing curve 684 (Line)
# Info    : [ 20%] Meshing curve 685 (Line)
# Info    : [ 20%] Meshing curve 686 (Line)
# Info    : [ 20%] Meshing curve 687 (Line)
# Info    : [ 20%] Meshing curve 688 (Line)
# Info    : [ 20%] Meshing curve 689 (Line)
# Info    : [ 20%] Meshing curve 690 (Line)
# Info    : [ 20%] Meshing curve 691 (Line)
# Info    : [ 20%] Meshing curve 692 (Line)
# Info    : [ 20%] Meshing curve 693 (Line)
# Info    : [ 20%] Meshing curve 694 (Line)
# Info    : [ 20%] Meshing curve 695 (Line)
# Info    : [ 20%] Meshing curve 696 (Line)
# Info    : [ 20%] Meshing curve 697 (Line)
# Info    : [ 20%] Meshing curve 698 (Line)
# Info    : [ 20%] Meshing curve 699 (Line)
# Info    : [ 20%] Meshing curve 700 (Line)
# Info    : [ 20%] Meshing curve 701 (Line)
# Info    : [ 20%] Meshing curve 702 (Line)
# Info    : [ 20%] Meshing curve 703 (Line)
# Info    : [ 20%] Meshing curve 704 (Line)
# Info    : [ 20%] Meshing curve 705 (Line)
# Info    : [ 20%] Meshing curve 706 (Line)
# Info    : [ 20%] Meshing curve 707 (Line)
# Info    : [ 20%] Meshing curve 708 (Line)
# Info    : [ 20%] Meshing curve 709 (Line)
# Info    : [ 20%] Meshing curve 710 (Line)
# Info    : [ 20%] Meshing curve 711 (Line)
# Info    : [ 20%] Meshing curve 712 (Line)
# Info    : [ 20%] Meshing curve 713 (Line)
# Info    : [ 20%] Meshing curve 714 (Line)
# Info    : [ 20%] Meshing curve 715 (Line)
# Info    : [ 20%] Meshing curve 716 (Line)
# Info    : [ 20%] Meshing curve 717 (Line)
# Info    : [ 20%] Meshing curve 718 (Line)
# Info    : [ 20%] Meshing curve 719 (Line)
# Info    : [ 20%] Meshing curve 720 (Line)
# Info    : [ 20%] Meshing curve 721 (Line)
# Info    : [ 20%] Meshing curve 722 (Line)
# Info    : [ 20%] Meshing curve 723 (Line)
# Info    : [ 20%] Meshing curve 724 (Line)
# Info    : [ 20%] Meshing curve 725 (Line)
# Info    : [ 20%] Meshing curve 726 (Line)
# Info    : [ 20%] Meshing curve 727 (Line)
# Info    : [ 20%] Meshing curve 728 (Line)
# Info    : [ 20%] Meshing curve 729 (Line)
# Info    : [ 20%] Meshing curve 730 (Line)
# Info    : [ 20%] Meshing curve 731 (Line)
# Info    : [ 20%] Meshing curve 732 (Line)
# Info    : [ 20%] Meshing curve 733 (Line)
# Info    : [ 20%] Meshing curve 734 (Line)
# Info    : [ 20%] Meshing curve 735 (Line)
# Info    : [ 20%] Meshing curve 736 (Line)
# Info    : [ 20%] Meshing curve 737 (Line)
# Info    : [ 20%] Meshing curve 738 (Line)
# Info    : [ 20%] Meshing curve 739 (Line)
# Info    : [ 20%] Meshing curve 740 (Line)
# Info    : [ 20%] Meshing curve 741 (Line)
# Info    : [ 20%] Meshing curve 742 (Line)
# Info    : [ 20%] Meshing curve 743 (Line)
# Info    : [ 20%] Meshing curve 744 (Line)
# Info    : [ 20%] Meshing curve 745 (Line)
# Info    : [ 20%] Meshing curve 746 (Line)
# Info    : [ 20%] Meshing curve 747 (Line)
# Info    : [ 20%] Meshing curve 748 (Line)
# Info    : [ 20%] Meshing curve 749 (Line)
# Info    : [ 20%] Meshing curve 750 (Line)
# Info    : [ 20%] Meshing curve 751 (Line)
# Info    : [ 20%] Meshing curve 752 (Line)
# Info    : [ 20%] Meshing curve 753 (Line)
# Info    : [ 20%] Meshing curve 754 (Line)
# Info    : [ 20%] Meshing curve 755 (Line)
# Info    : [ 20%] Meshing curve 756 (Line)
# Info    : [ 20%] Meshing curve 757 (Line)
# Info    : [ 20%] Meshing curve 758 (Line)
# Info    : [ 20%] Meshing curve 759 (Line)
# Info    : [ 20%] Meshing curve 760 (Line)
# Info    : [ 20%] Meshing curve 761 (Line)
# Info    : [ 20%] Meshing curve 762 (Line)
# Info    : [ 20%] Meshing curve 763 (Line)
# Info    : [ 20%] Meshing curve 764 (Line)
# Info    : [ 20%] Meshing curve 765 (Line)
# Info    : [ 20%] Meshing curve 766 (Line)
# Info    : [ 20%] Meshing curve 767 (Line)
# Info    : [ 20%] Meshing curve 768 (Line)
# Info    : [ 20%] Meshing curve 769 (Line)
# Info    : [ 20%] Meshing curve 770 (Line)
# Info    : [ 20%] Meshing curve 771 (Line)
# Info    : [ 20%] Meshing curve 772 (Line)
# Info    : [ 20%] Meshing curve 773 (Line)
# Info    : [ 20%] Meshing curve 774 (Line)
# Info    : [ 20%] Meshing curve 775 (Line)
# Info    : [ 20%] Meshing curve 776 (Line)
# Info    : [ 20%] Meshing curve 777 (Line)
# Info    : [ 20%] Meshing curve 778 (Line)
# Info    : [ 20%] Meshing curve 779 (Line)
# Info    : [ 20%] Meshing curve 780 (Line)
# Info    : [ 20%] Meshing curve 781 (Line)
# Info    : [ 20%] Meshing curve 782 (Line)
# Info    : [ 20%] Meshing curve 783 (Line)
# Info    : [ 20%] Meshing curve 784 (Line)
# Info    : [ 20%] Meshing curve 785 (Line)
# Info    : [ 20%] Meshing curve 786 (Line)
# Info    : [ 20%] Meshing curve 787 (Line)
# Info    : [ 20%] Meshing curve 788 (Line)
# Info    : [ 20%] Meshing curve 789 (Line)
# Info    : [ 20%] Meshing curve 790 (Line)
# Info    : [ 20%] Meshing curve 791 (Line)
# Info    : [ 20%] Meshing curve 792 (Line)
# Info    : [ 20%] Meshing curve 793 (Line)
# Info    : [ 20%] Meshing curve 794 (Line)
# Info    : [ 20%] Meshing curve 795 (Line)
# Info    : [ 20%] Meshing curve 796 (Line)
# Info    : [ 40%] Meshing curve 1068 (Line)
# Info    : [ 40%] Meshing curve 1069 (Line)
# Info    : [ 40%] Meshing curve 1070 (Line)
# Info    : [ 40%] Meshing curve 1071 (Line)
# Info    : [ 40%] Meshing curve 1072 (Line)
# Info    : [ 40%] Meshing curve 1073 (Line)
# Info    : [ 40%] Meshing curve 1074 (Line)
# Info    : [ 40%] Meshing curve 1075 (Line)
# Info    : [ 40%] Meshing curve 1076 (Line)
# Info    : [ 40%] Meshing curve 1077 (Line)
# Info    : [ 40%] Meshing curve 1078 (Line)
# Info    : [ 40%] Meshing curve 1079 (Line)
# Info    : [ 40%] Meshing curve 1080 (Line)
# Info    : [ 40%] Meshing curve 1081 (Line)
# Info    : [ 40%] Meshing curve 1082 (Line)
# Info    : [ 40%] Meshing curve 1083 (Line)
# Info    : [ 40%] Meshing curve 1084 (Line)
# Info    : [ 40%] Meshing curve 1085 (Line)
# Info    : [ 40%] Meshing curve 1086 (Line)
# Info    : [ 40%] Meshing curve 1087 (Line)
# Info    : [ 40%] Meshing curve 1088 (Line)
# Info    : [ 40%] Meshing curve 1089 (Line)
# Info    : [ 40%] Meshing curve 1090 (Line)
# Info    : [ 40%] Meshing curve 1091 (Line)
# Info    : [ 40%] Meshing curve 1092 (Line)
# Info    : [ 40%] Meshing curve 1093 (Line)
# Info    : [ 40%] Meshing curve 1094 (Line)
# Info    : [ 40%] Meshing curve 1095 (Line)
# Info    : [ 40%] Meshing curve 1096 (Line)
# Info    : [ 40%] Meshing curve 1097 (Line)
# Info    : [ 40%] Meshing curve 1098 (Line)
# Info    : [ 40%] Meshing curve 1099 (Line)
# Info    : [ 40%] Meshing curve 1100 (Line)
# Info    : [ 40%] Meshing curve 1101 (Line)
# Info    : [ 40%] Meshing curve 1102 (Line)
# Info    : [ 40%] Meshing curve 1103 (Line)
# Info    : [ 40%] Meshing curve 1104 (Line)
# Info    : [ 40%] Meshing curve 1105 (Line)
# Info    : [ 40%] Meshing curve 1106 (Line)
# Info    : [ 40%] Meshing curve 1107 (Line)
# Info    : [ 40%] Meshing curve 1108 (Line)
# Info    : [ 40%] Meshing curve 1109 (Line)
# Info    : [ 40%] Meshing curve 1110 (Line)
# Info    : [ 40%] Meshing curve 1111 (Line)
# Info    : [ 40%] Meshing curve 1112 (Line)
# Info    : [ 40%] Meshing curve 1113 (Line)
# Info    : [ 40%] Meshing curve 1114 (Line)
# Info    : [ 40%] Meshing curve 1115 (Line)
# Info    : [ 40%] Meshing curve 1116 (Line)
# Info    : [ 40%] Meshing curve 1117 (Line)
# Info    : [ 40%] Meshing curve 1118 (Line)
# Info    : [ 40%] Meshing curve 1119 (Line)
# Info    : [ 40%] Meshing curve 1120 (Line)
# Info    : [ 40%] Meshing curve 1121 (Line)
# Info    : [ 40%] Meshing curve 1122 (Line)
# Info    : [ 40%] Meshing curve 1123 (Line)
# Info    : [ 40%] Meshing curve 1124 (Line)
# Info    : [ 40%] Meshing curve 1125 (Line)
# Info    : [ 40%] Meshing curve 1126 (Line)
# Info    : [ 40%] Meshing curve 1127 (Line)
# Info    : [ 40%] Meshing curve 1128 (Line)
# Info    : [ 40%] Meshing curve 1129 (Line)
# Info    : [ 40%] Meshing curve 1130 (Line)
# Info    : [ 40%] Meshing curve 1131 (Line)
# Info    : [ 40%] Meshing curve 1132 (Line)
# Info    : [ 40%] Meshing curve 1133 (Line)
# Info    : [ 40%] Meshing curve 1134 (Line)
# Info    : [ 40%] Meshing curve 1135 (Line)
# Info    : [ 40%] Meshing curve 1136 (Line)
# Info    : [ 40%] Meshing curve 1137 (Line)
# Info    : [ 40%] Meshing curve 1138 (Line)
# Info    : [ 40%] Meshing curve 1139 (Line)
# Info    : [ 40%] Meshing curve 1140 (Line)
# Info    : [ 40%] Meshing curve 1141 (Line)
# Info    : [ 40%] Meshing curve 1142 (Line)
# Info    : [ 40%] Meshing curve 1143 (Line)
# Info    : [ 40%] Meshing curve 1144 (Line)
# Info    : [ 40%] Meshing curve 1145 (Line)
# Info    : [ 40%] Meshing curve 1146 (Line)
# Info    : [ 40%] Meshing curve 1147 (Line)
# Info    : [ 40%] Meshing curve 1148 (Line)
# Info    : [ 40%] Meshing curve 1149 (Line)
# Info    : [ 40%] Meshing curve 1150 (Line)
# Info    : [ 40%] Meshing curve 1151 (Line)
# Info    : [ 40%] Meshing curve 1152 (Line)
# Info    : [ 40%] Meshing curve 1153 (Line)
# Info    : [ 40%] Meshing curve 1154 (Line)
# Info    : [ 40%] Meshing curve 1155 (Line)
# Info    : [ 40%] Meshing curve 1156 (Line)
# Info    : [ 40%] Meshing curve 1157 (Line)
# Info    : [ 40%] Meshing curve 1158 (Line)
# Info    : [ 40%] Meshing curve 1159 (Line)
# Info    : [ 40%] Meshing curve 1160 (Line)
# Info    : [ 40%] Meshing curve 1161 (Line)
# Info    : [ 40%] Meshing curve 1162 (Line)
# Info    : [ 40%] Meshing curve 1163 (Line)
# Info    : [ 40%] Meshing curve 1164 (Line)
# Info    : [ 40%] Meshing curve 1165 (Line)
# Info    : [ 40%] Meshing curve 1166 (Line)
# Info    : [ 40%] Meshing curve 1167 (Line)
# Info    : [ 40%] Meshing curve 1168 (Line)
# Info    : [ 40%] Meshing curve 1169 (Line)
# Info    : [ 40%] Meshing curve 1170 (Line)
# Info    : [ 40%] Meshing curve 1171 (Line)
# Info    : [ 40%] Meshing curve 1172 (Line)
# Info    : [ 40%] Meshing curve 1173 (Line)
# Info    : [ 40%] Meshing curve 1174 (Line)
# Info    : [ 40%] Meshing curve 1175 (Line)
# Info    : [ 40%] Meshing curve 1176 (Line)
# Info    : [ 40%] Meshing curve 1177 (Line)
# Info    : [ 40%] Meshing curve 1178 (Line)
# Info    : [ 40%] Meshing curve 1179 (Line)
# Info    : [ 40%] Meshing curve 1180 (Line)
# Info    : [ 40%] Meshing curve 1181 (Line)
# Info    : [ 40%] Meshing curve 1182 (Line)
# Info    : [ 40%] Meshing curve 1183 (Line)
# Info    : [ 40%] Meshing curve 1184 (Line)
# Info    : [ 40%] Meshing curve 1185 (Line)
# Info    : [ 40%] Meshing curve 1186 (Line)
# Info    : [ 40%] Meshing curve 1187 (Line)
# Info    : [ 40%] Meshing curve 1188 (Line)
# Info    : [ 40%] Meshing curve 1189 (Line)
# Info    : [ 40%] Meshing curve 1190 (Line)
# Info    : [ 40%] Meshing curve 1191 (Line)
# Info    : [ 40%] Meshing curve 1192 (Line)
# Info    : [ 40%] Meshing curve 1193 (Line)
# Info    : [ 40%] Meshing curve 1194 (Line)
# Info    : [ 40%] Meshing curve 1195 (Line)
# Info    : [ 40%] Meshing curve 1196 (Line)
# Info    : [ 40%] Meshing curve 1197 (Line)
# Info    : [ 40%] Meshing curve 1198 (Line)
# Info    : [ 40%] Meshing curve 1199 (Line)
# Info    : [ 40%] Meshing curve 1200 (Line)
# Info    : [ 40%] Meshing curve 1201 (Line)
# Info    : [ 40%] Meshing curve 1202 (Line)
# Info    : [ 40%] Meshing curve 1203 (Line)
# Info    : [ 40%] Meshing curve 1204 (Line)
# Info    : [ 40%] Meshing curve 1205 (Line)
# Info    : [ 40%] Meshing curve 1206 (Line)
# Info    : [ 40%] Meshing curve 1207 (Line)
# Info    : [ 40%] Meshing curve 1208 (Line)
# Info    : [ 40%] Meshing curve 1209 (Line)
# Info    : [ 40%] Meshing curve 1210 (Line)
# Info    : [ 40%] Meshing curve 1211 (Line)
# Info    : [ 40%] Meshing curve 1212 (Line)
# Info    : [ 40%] Meshing curve 1213 (Line)
# Info    : [ 40%] Meshing curve 1214 (Line)
# Info    : [ 40%] Meshing curve 1215 (Line)
# Info    : [ 40%] Meshing curve 1216 (Line)
# Info    : [ 40%] Meshing curve 1217 (Line)
# Info    : [ 40%] Meshing curve 1218 (Line)
# Info    : [ 40%] Meshing curve 1219 (Line)
# Info    : [ 40%] Meshing curve 1220 (Line)
# Info    : [ 40%] Meshing curve 1221 (Line)
# Info    : [ 40%] Meshing curve 1222 (Line)
# Info    : [ 40%] Meshing curve 1223 (Line)
# Info    : [ 40%] Meshing curve 1224 (Line)
# Info    : [ 40%] Meshing curve 1225 (Line)
# Info    : [ 40%] Meshing curve 1226 (Line)
# Info    : [ 40%] Meshing curve 1227 (Line)
# Info    : [ 40%] Meshing curve 1228 (Line)
# Info    : [ 40%] Meshing curve 1229 (Line)
# Info    : [ 40%] Meshing curve 1230 (Line)
# Info    : [ 40%] Meshing curve 1231 (Line)
# Info    : [ 40%] Meshing curve 1232 (Line)
# Info    : [ 40%] Meshing curve 1233 (Line)
# Info    : [ 40%] Meshing curve 1234 (Line)
# Info    : [ 40%] Meshing curve 1235 (Line)
# Info    : [ 40%] Meshing curve 1236 (Line)
# Info    : [ 40%] Meshing curve 1237 (Line)
# Info    : [ 40%] Meshing curve 1238 (Line)
# Info    : [ 40%] Meshing curve 1239 (Line)
# Info    : [ 40%] Meshing curve 1240 (Line)
# Info    : [ 40%] Meshing curve 1241 (Line)
# Info    : [ 40%] Meshing curve 1242 (Line)
# Info    : [ 40%] Meshing curve 1243 (Line)
# Info    : [ 40%] Meshing curve 1244 (Line)
# Info    : [ 40%] Meshing curve 1245 (Line)
# Info    : [ 40%] Meshing curve 1246 (Line)
# Info    : [ 40%] Meshing curve 1247 (Line)
# Info    : [ 90%] Meshing surface 25 order 2
# Info    : [ 90%] Meshing surface 26 order 2
# Info    : [ 90%] Meshing surface 27 order 2
# Info    : [ 90%] Meshing surface 28 order 2
# Info    : [ 90%] Meshing surface 29 order 2
# Info    : [ 90%] Meshing surface 30 order 2
# Info    : [ 90%] Meshing surface 31 order 2
# Info    : [ 90%] Meshing surface 32 order 2
# Info    : [ 90%] Meshing surface 33 order 2
# Info    : [ 90%] Meshing surface 34 order 2
# Info    : [ 90%] Meshing surface 35 order 2
# Info    : [ 90%] Meshing surface 36 order 2
# Info    : [ 90%] Meshing surface 37 order 2
# Info    : [ 90%] Meshing surface 38 order 2
# Info    : [ 90%] Meshing surface 39 order 2
# Info    : [ 90%] Meshing surface 40 order 2
# Info    : [ 90%] Meshing surface 41 order 2
# Info    : [ 90%] Meshing surface 42 order 2
# Info    : [ 90%] Meshing surface 43 order 2
# Info    : [ 90%] Meshing surface 44 order 2
# Info    : [ 90%] Meshing surface 45 order 2
# Info    : [ 90%] Meshing surface 46 order 2
# Info    : [ 90%] Meshing surface 47 order 2
# Info    : [ 90%] Meshing surface 48 order 2
# Info    : [ 90%] Meshing surface 49 order 2
# Info    : [ 90%] Meshing surface 50 order 2
# Info    : [ 90%] Meshing surface 51 order 2
# Info    : [ 90%] Meshing surface 52 order 2
# Info    : [ 90%] Meshing surface 53 order 2
# Info    : [ 90%] Meshing surface 54 order 2
# Info    : [ 90%] Meshing surface 55 order 2
# Info    : [ 90%] Meshing surface 56 order 2
# Info    : [ 90%] Meshing surface 57 order 2
# Info    : [ 90%] Meshing surface 58 order 2
# Info    : [ 90%] Meshing surface 59 order 2
# Info    : [100%] Meshing surface 60 order 2
# Info    : [100%] Meshing surface 61 order 2
# Info    : [100%] Meshing surface 62 order 2
# Info    : [100%] Meshing surface 63 order 2
# Info    : [100%] Meshing surface 64 order 2
# Info    : [100%] Meshing surface 65 order 2
# Info    : [100%] Meshing surface 66 order 2
# Info    : [100%] Meshing surface 67 order 2
# Info    : [100%] Meshing surface 68 order 2
# Info    : [100%] Meshing surface 69 order 2
# Info    : [100%] Meshing surface 70 order 2
# Info    : [100%] Meshing surface 71 order 2
# Info    : [100%] Meshing surface 72 order 2
# Info    : [100%] Meshing surface 73 order 2
# Info    : [100%] Meshing surface 74 order 2
# Info    : [100%] Meshing surface 75 order 2
# Info    : [100%] Meshing surface 76 order 2
# Info    : [100%] Meshing surface 77 order 2
# Info    : [100%] Meshing surface 78 order 2
# Info    : [100%] Meshing surface 79 order 2
# Info    : [100%] Meshing surface 80 order 2
# Info    : [100%] Meshing surface 81 order 2
# Info    : [100%] Meshing surface 82 order 2
# Info    : [100%] Meshing surface 83 order 2
# Info    : [100%] Meshing surface 84 order 2
# Info    : [100%] Meshing surface 85 order 2
# Info    : [100%] Meshing surface 86 order 2
# Info    : [100%] Meshing surface 87 order 2
# Info    : [100%] Meshing surface 88 order 2
# Info    : [100%] Meshing surface 89 order 2
# Info    : [100%] Meshing surface 90 order 2
# Info    : [100%] Meshing surface 91 order 2
# Info    : [100%] Meshing surface 92 order 2
# Info    : [100%] Meshing surface 93 order 2
# Info    : [100%] Meshing surface 94 order 2
# Info    : [100%] Meshing surface 95 order 2
# Info    : [100%] Meshing surface 96 order 2
# Info    : [100%] Meshing surface 97 order 2
# Info    : [100%] Meshing surface 98 order 2
# Info    : [100%] Meshing surface 99 order 2
# Info    : [100%] Meshing surface 100 order 2
# Info    : [100%] Meshing surface 101 order 2
# Info    : [100%] Meshing surface 102 order 2
# Info    : [100%] Meshing surface 103 order 2
# Info    : [100%] Meshing surface 104 order 2
# Info    : [100%] Meshing surface 105 order 2
# Info    : [100%] Meshing surface 106 order 2
# Info    : [100%] Meshing surface 107 order 2
# Info    : [100%] Meshing surface 108 order 2
# Info    : [100%] Meshing surface 109 order 2
# Info    : [100%] Meshing surface 110 order 2
# Info    : [100%] Meshing surface 111 order 2
# Info    : [100%] Meshing surface 112 order 2
# Info    : [100%] Meshing surface 113 order 2
# Info    : [100%] Meshing surface 114 order 2
# Info    : [100%] Meshing surface 115 order 2
# Info    : [100%] Meshing surface 116 order 2
# Info    : [100%] Meshing surface 117 order 2
# Info    : [100%] Meshing surface 118 order 2
# Info    : [100%] Meshing surface 119 order 2
# Info    : [100%] Meshing surface 120 order 2
# Info    : [100%] Meshing surface 121 order 2
# Info    : [100%] Meshing surface 122 order 2
# Info    : [100%] Meshing surface 123 order 2
# Info    : [100%] Meshing surface 124 order 2
# Info    : [100%] Meshing surface 125 order 2
# Info    : [100%] Meshing surface 126 order 2
# Info    : [100%] Meshing surface 127 order 2
# Info    : [100%] Meshing surface 128 order 2
# Info    : [100%] Meshing surface 129 order 2
# Info    : [100%] Meshing surface 130 order 2
# Info    : [100%] Meshing surface 131 order 2
# Info    : [100%] Meshing surface 132 order 2
# Info    : [100%] Meshing surface 133 order 2
# Info    : [100%] Meshing surface 134 order 2
# Info    : [100%] Meshing surface 135 order 2
# Info    : [100%] Meshing surface 136 order 2
# Info    : [100%] Meshing surface 137 order 2
# Info    : [100%] Meshing surface 138 order 2
# Info    : [100%] Meshing surface 139 order 2
# Info    : [100%] Meshing surface 140 order 2
# Info    : [100%] Meshing surface 141 order 2
# Info    : [100%] Meshing surface 142 order 2
# Info    : [100%] Meshing surface 143 order 2
# Info    : [100%] Meshing surface 144 order 2
# Info    : [100%] Meshing surface 145 order 2
# Info    : [100%] Meshing surface 146 order 2
# Info    : [100%] Meshing surface 147 order 2
# Info    : [100%] Meshing surface 148 order 2
# Info    : [100%] Meshing surface 149 order 2
# Info    : [100%] Meshing surface 150 order 2
# Info    : [100%] Meshing surface 151 order 2
# Info    : [100%] Meshing surface 152 order 2
# Info    : [100%] Meshing surface 153 order 2
# Info    : [100%] Meshing surface 154 order 2
# Info    : [100%] Meshing surface 155 order 2
# Info    : [100%] Meshing surface 156 order 2
# Info    : [100%] Meshing surface 157 order 2
# Info    : [100%] Meshing surface 158 order 2
# Info    : [100%] Meshing surface 159 order 2
# Info    : [100%] Meshing surface 160 order 2
# Info    : [100%] Meshing surface 161 order 2
# Info    : [100%] Meshing surface 162 order 2
# Info    : [100%] Meshing surface 163 order 2
# Info    : [100%] Meshing surface 164 order 2
# Info    : [100%] Meshing surface 165 order 2
# Info    : [100%] Meshing surface 166 order 2
# Info    : [100%] Meshing surface 167 order 2
# Info    : [100%] Meshing surface 168 order 2
# Info    : [100%] Meshing surface 169 order 2
# Info    : [100%] Meshing surface 170 order 2
# Info    : [100%] Meshing surface 171 order 2
# Info    : [100%] Meshing surface 172 order 2
# Info    : [100%] Meshing surface 173 order 2
# Info    : [100%] Meshing surface 174 order 2
# Info    : [100%] Meshing surface 175 order 2
# Info    : [100%] Meshing surface 176 order 2
# Info    : [100%] Meshing surface 177 order 2
# Info    : [100%] Meshing surface 178 order 2
# Info    : [100%] Meshing surface 179 order 2
# Info    : [100%] Meshing surface 180 order 2
# Info    : [100%] Meshing surface 181 order 2
# Info    : [100%] Meshing surface 182 order 2
# Info    : [100%] Meshing surface 183 order 2
# Info    : [100%] Meshing surface 184 order 2
# Info    : [100%] Meshing surface 185 order 2
# Info    : [100%] Meshing surface 186 order 2
# Info    : [100%] Meshing surface 187 order 2
# Info    : [100%] Meshing surface 188 order 2
# Info    : [100%] Meshing surface 189 order 2
# Info    : [100%] Meshing surface 190 order 2
# Info    : [100%] Meshing surface 191 order 2
# Info    : [100%] Meshing surface 192 order 2
# Info    : [100%] Meshing surface 193 order 2
# Info    : [100%] Meshing surface 194 order 2
# Info    : [100%] Meshing surface 195 order 2
# Info    : [100%] Meshing surface 196 order 2
# Info    : [100%] Meshing surface 197 order 2
# Info    : [100%] Meshing surface 198 order 2
# Info    : [100%] Meshing surface 199 order 2
# Info    : [100%] Meshing surface 200 order 2
# Info    : [100%] Meshing surface 201 order 2
# Info    : [100%] Meshing surface 202 order 2
# Info    : [100%] Meshing surface 203 order 2
# Info    : [100%] Meshing surface 204 order 2
# Info    : [100%] Meshing surface 205 order 2
# Info    : [100%] Meshing surface 206 order 2
# Info    : [100%] Meshing surface 207 order 2
# Info    : [100%] Meshing surface 208 order 2
# Info    : [100%] Meshing surface 209 order 2
# Info    : [100%] Meshing surface 210 order 2
# Info    : [100%] Meshing surface 211 order 2
# Info    : [100%] Meshing surface 212 order 2
# Info    : [100%] Meshing surface 213 order 2
# Info    : [100%] Meshing surface 214 order 2
# Info    : [100%] Meshing surface 215 order 2
# Info    : [100%] Meshing surface 216 order 2
# Info    : [100%] Meshing surface 217 order 2
# Info    : [100%] Meshing surface 218 order 2
# Info    : [100%] Meshing surface 219 order 2
# Info    : [100%] Meshing surface 220 order 2
# Info    : [100%] Meshing surface 221 order 2
# Info    : [100%] Meshing surface 222 order 2
# Info    : [100%] Meshing surface 223 order 2
# Info    : [100%] Meshing surface 224 order 2
# Info    : [100%] Meshing surface 225 order 2
# Info    : [100%] Meshing surface 226 order 2
# Info    : [100%] Meshing surface 227 order 2
# Info    : [100%] Meshing surface 228 order 2
# Info    : [100%] Meshing surface 229 order 2
# Info    : [100%] Meshing surface 230 order 2
# Info    : [100%] Meshing surface 231 order 2
# Info    : [100%] Meshing surface 232 order 2
# Info    : [100%] Meshing surface 233 order 2
# Info    : [100%] Meshing surface 234 order 2
# Info    : [100%] Meshing surface 235 order 2
# Info    : [100%] Meshing surface 236 order 2
# Info    : [100%] Meshing surface 237 order 2
# Info    : [100%] Meshing surface 238 order 2
# Info    : [100%] Meshing surface 239 order 2
# Info    : [100%] Meshing surface 240 order 2
# Info    : [100%] Meshing surface 241 order 2
# Info    : [100%] Meshing surface 242 order 2
# Info    : [100%] Meshing surface 243 order 2
# Info    : [100%] Meshing surface 244 order 2
# Info    : [100%] Meshing surface 245 order 2
# Info    : [100%] Meshing surface 246 order 2
# Info    : [100%] Meshing surface 247 order 2
# Info    : [100%] Meshing surface 248 order 2
# Info    : [100%] Meshing surface 249 order 2
# Info    : [100%] Meshing surface 250 order 2
# Info    : [100%] Meshing surface 251 order 2
# Info    : [100%] Meshing surface 252 order 2
# Info    : [100%] Meshing surface 253 order 2
# Info    : [100%] Meshing surface 254 order 2
# Info    : [100%] Meshing surface 255 order 2
# Info    : [100%] Meshing surface 256 order 2
# Info    : [100%] Meshing surface 257 order 2
# Info    : [100%] Meshing surface 258 order 2
# Info    : [100%] Meshing surface 259 order 2
# Info    : [100%] Meshing surface 260 order 2
# Info    : [100%] Meshing surface 261 order 2
# Info    : [100%] Meshing surface 262 order 2
# Info    : [100%] Meshing surface 263 order 2
# Info    : [100%] Meshing surface 264 order 2
# Info    : [100%] Meshing surface 265 order 2
# Info    : [100%] Meshing surface 266 order 2
# Info    : [100%] Meshing surface 267 order 2
# Info    : [100%] Meshing surface 268 order 2
# Info    : [100%] Meshing surface 269 order 2
# Info    : [100%] Meshing surface 270 order 2
# Info    : [100%] Meshing surface 271 order 2
# Info    : [100%] Meshing surface 272 order 2
# Info    : [100%] Meshing surface 273 order 2
# Info    : [100%] Meshing surface 274 order 2
# Info    : [100%] Meshing surface 275 order 2
# Info    : [100%] Meshing surface 276 order 2
# Info    : [100%] Meshing surface 277 order 2
# Info    : [100%] Meshing surface 278 order 2
# Info    : [100%] Meshing surface 279 order 2
# Info    : [100%] Meshing surface 280 order 2
# Info    : [100%] Meshing surface 281 order 2
# Info    : [100%] Meshing surface 282 order 2
# Info    : [100%] Meshing surface 283 order 2
# Info    : [100%] Meshing surface 284 order 2
# Info    : [100%] Meshing surface 285 order 2
# Info    : [100%] Meshing surface 286 order 2
# Info    : [100%] Meshing surface 287 order 2
# Info    : [100%] Meshing surface 288 order 2
# Info    : [100%] Meshing volume 1 order 2
# Warning : Surface mesh: worst distortion = -1.4662 (avg = 0.992671, 16 elements with jac. < 0); worst gamma = 0.0119429
# Warning : Volume mesh: worst distortion = -1.52726 (avg = 0.990561, 17 elements with jac. < 0)
# Info    : Done meshing order 2 (Wall 16.736s, CPU 16.7549s)
# Info    : 408979 nodes 343013 elements
# meshed in 28.7 s
# Warning : ------------------------------
# Warning : Mesh generation error summary
# Warning :     2 warnings
# Warning :     0 errors
# Warning : Check the full log for details
# Warning : ------------------------------

# %%
gmsh.write('full_mesh.msh')  # portable fallback for a separate dolfinx env
# Out:
# Info    : Writing 'full_mesh.msh'...
# Info    : Done writing 'full_mesh.msh'

# %% [markdown]
# ### Step 4: classify nodes + clamp metadata
#
# Inverse-map every gmsh node back into the base-coil $(\varphi, u, v)$ parametrisation to separate conductor from beam/steel, evaluate clamp Winkler weights, and write a plain `.npz` (for ``beam_dolfinx.py``) plus a VTU for sanity checking. Lorentz / Biot–Savart body force is **not** computed here — ``beam_dolfinx.py`` evaluates it at volume quadrature points on the imported mesh.
#
# **Known limitation.** `occ.fuse` dissolves the coil/beam interface, so tets straddle the conductor boundary. If that matters for validation, switch upstream to `occ.fragment` (keeps the interface mesh-conforming and tags volumes directly).

# %%
# ============================================================================
# Step 4A: inverse map (Option B) — classify nodes as conductor vs beam/steel
# ============================================================================
# Push every gmsh node back through the symmetry transform and the sweep map
#     x = gamma(phi) + (w1/2) u p(phi) + (w2/2) v q(phi)
# to recover (phi, u, v) in the *base* coil frame. Nodes with |u|,|v| <= 1
# are conductor; the rest are beam/steel.

import interpax
from scipy.spatial import cKDTree

# Mesh nodes from the live gmsh session (must run before gmsh.finalize()).
# getNodes() also returns nodes on the leftover cross-section ring wires, which
# addThruSections keeps alive despite the occ.remove() in Step 2. Those nodes
# are absent from full_mesh.msh, so keep only the ones a TET10 actually uses.
node_tags, node_coords, _ = gmsh.model.mesh.getNodes()
X = np.asarray(node_coords, dtype=np.float64).reshape(-1, 3)
node_tags = np.asarray(node_tags, dtype=np.int64)

_, _enodes = gmsh.model.mesh.getElementsByType(11)  # 11 = TET10
_keep = np.isin(node_tags, np.unique(np.asarray(_enodes, dtype=np.int64)))
X, node_tags = X[_keep], node_tags[_keep]
N = X.shape[0]
print(f'gmsh nodes: {N} (dropped {int((~_keep).sum())} not used by any TET10)')

nfp, stellsym = support.nfp, support.stellsym
n_base = len(Jstress.fem.meshes)
flip_list = (False, True) if stellsym else (False,)
flip_Q = np.diag([1.0, -1.0, -1.0])

# Same ordered transform list as coil_fem.geo.symmetries (identity kept).
# Q maps base -> image; inverse is Q.T since each Q is orthogonal (det ±1).
Q_list = []
for k in range(nfp):
    phi_k = 2.0 * np.pi * k / nfp
    c, s = np.cos(phi_k), np.sin(phi_k)
    rot = np.array([[c, -s, 0.0], [s, c, 0.0], [0.0, 0.0, 1.0]])
    for flip in flip_list:
        Q_list.append(flip_Q @ rot if flip else rot)
Q_list = np.asarray(Q_list)          # (n_sym, 3, 3)
n_sym = Q_list.shape[0]

# Dense centreline + RMF frame samples per base coil (uniform grid required
# for FramedCurveRMFJAX.rotated_frame_eval; scattered phi uses interpax).
N_PHI = 4096
phi_s = np.linspace(0.0, 1.0, N_PHI, endpoint=False)
w1 = float(mesh_options['w1'])
w2 = float(mesh_options['w2'])
dist_cut = 0.5 * np.hypot(w1, w2) * 1.05
# Tolerance for node selection
uv_tol = 2e-2

# Per-coil samples in BASE frame (gamma, p, q on the dense grid).
gamma_s = []   # list of (N_PHI, 3)
p_s = []
q_s = []
for mesh in Jstress.fem.meshes:
    fc = mesh.framed_curve
    g = np.asarray(fc.curve.gamma_eval(phi_s))
    _, p, q = fc.rotated_frame_eval(phi_s)
    gamma_s.append(np.asarray(g))
    p_s.append(np.asarray(p))
    q_s.append(np.asarray(q))

# One cKDTree over all image centreline samples.
sample_pts = []
sample_lab = []   # (s, i, phi_index)
for s in range(n_sym):
    Q = Q_list[s]
    for i in range(n_base):
        pts_img = gamma_s[i] @ Q.T          # (N_PHI, 3)
        sample_pts.append(pts_img)
        labs = np.empty((N_PHI, 3), dtype=np.int32)
        labs[:, 0] = s
        labs[:, 1] = i
        labs[:, 2] = np.arange(N_PHI)
        sample_lab.append(labs)
sample_pts = np.vstack(sample_pts)
sample_lab = np.vstack(sample_lab)
tree = cKDTree(sample_pts)
print(f'KD-tree samples: {sample_pts.shape[0]} '
      f'({n_sym} sectors x {n_base} coils x {N_PHI})')

dist, nn = tree.query(X, k=3)
# Candidate labels for each of the 3 nearest samples.
cand_lab = sample_lab[nn]                 # (N, 3, 3) -> (s, i, phi_idx)

owner_sym = np.full(N, -1, dtype=np.int8)
owner_coil = np.full(N, -1, dtype=np.int8)
phi_out = np.zeros(N, dtype=np.float32)
u_out = np.zeros(N, dtype=np.float32)
v_out = np.zeros(N, dtype=np.float32)

# Process candidates: for each node, try up to 3 nearest (s, i) pairs.
# Vectorise Newton refinement per (candidate slot, coil) batch for speed.
for cand in range(3):
    unset = owner_coil < 0
    if not unset.any():
        break
    idxs = np.where(unset)[0]
    s_c = cand_lab[idxs, cand, 0]
    i_c = cand_lab[idxs, cand, 1]
    phi0 = phi_s[cand_lab[idxs, cand, 2]]
    d_c = dist[idxs, cand]

    # Reject far candidates early.
    far = d_c > dist_cut
    # Group remaining by coil index for batched gamma_eval / frame interp.
    keep_mask = ~far
    for i in range(n_base):
        m = keep_mask & (i_c == i)
        if not m.any():
            continue
        sel = idxs[m]
        s_sel = s_c[m]
        phi_guess = phi0[m].astype(np.float64)

        # Inverse transform into base frame: y = X @ Q  (Q orthogonal).
        Qs = Q_list[s_sel]                              # (n, 3, 3)
        y = np.einsum('ni,nij->nj', X[sel], Qs)         # (n, 3)

        # 2 Newton steps on g(phi) = (y - gamma).dot(gammadash) = 0.
        fc = Jstress.fem.meshes[i].framed_curve
        curve = fc.curve
        phi_n = phi_guess.copy()
        for _ in range(2):
            g0 = np.asarray(curve.gamma_eval(phi_n, 0))
            g1 = np.asarray(curve.gamma_eval(phi_n, 1))
            g2 = np.asarray(curve.gamma_eval(phi_n, 2))
            dvec = y - g0
            g = np.sum(dvec * g1, axis=1)
            gp = -np.sum(g1 * g1, axis=1) + np.sum(dvec * g2, axis=1)
            phi_n = phi_n - g / np.where(np.abs(gp) < 1e-30, 1e-30, gp)
        phi_n = np.mod(phi_n, 1.0)

        # Frame at refined phi via periodic cubic interp off the dense grid.
        p_i = np.asarray(interpax.interp1d(
            phi_n, phi_s, p_s[i], method='cubic2', period=1.0,
        ))
        q_i = np.asarray(interpax.interp1d(
            phi_n, phi_s, q_s[i], method='cubic2', period=1.0,
        ))
        g0 = np.asarray(curve.gamma_eval(phi_n, 0))
        dvec = y - g0
        u = 2.0 * np.sum(dvec * p_i, axis=1) / w1
        v = 2.0 * np.sum(dvec * q_i, axis=1) / w2
        inside = (np.abs(u) <= 1.0 + uv_tol) & (np.abs(v) <= 1.0 + uv_tol)

        take = sel[inside]
        owner_sym[take] = s_sel[inside].astype(np.int8)
        owner_coil[take] = i
        phi_out[take] = phi_n[inside].astype(np.float32)
        u_out[take] = u[inside].astype(np.float32)
        v_out[take] = v[inside].astype(np.float32)

n_cond = int((owner_coil >= 0).sum())
print(f'conductor nodes: {n_cond} / {N} ({100 * n_cond / N:.1f}%)')
print(f'beam/steel nodes: {N - n_cond}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 9
#       1 # ============================================================================
#       2 # Step 4A: inverse map (Option B) — classify nodes as conductor vs beam/steel
#       3 # ============================================================================
#    (...)      6 # to recover (phi, u, v) in the *base* coil frame. Nodes with |u|,|v| <= 1
#       7 # are conductor; the rest are beam/steel.
# ----> 9 import interpax
#      10 from scipy.spatial import cKDTree
#      12 # Mesh nodes from the live gmsh session (must run before gmsh.finalize()).
#      13 # getNodes() also returns nodes on the leftover cross-section ring wires, which
#      14 # addThruSections keeps alive despite the occ.remove() in Step 2. Those nodes
#      15 # are absent from full_mesh.msh, so keep only the ones a TET10 actually uses.
#
# File /scratch/miniconda3/envs/rod/lib/python3.12/site-packages/interpax/__init__.py:4
#       1 """interpax: interpolation and function approximation with JAX."""
#       3 from . import _version
# ----> 4 from ._fd_derivs import approx_df
#       5 from ._fourier import fft_interp1d, fft_interp2d
#       6 from ._ppoly import (
#       7     Akima1DInterpolator,
#       8     CubicHermiteSpline,
#    (...)     11     PPoly,
#      12 )
#
# File /scratch/miniconda3/envs/rod/lib/python3.12/site-packages/interpax/_fd_derivs.py:6
#       3 import jax.numpy as jnp
#       4 import lineax as lx
# ----> 6 from .utils import asarray_inexact, errorif
#       9 def approx_df(
#      10     x: jax.Array, f: jax.Array, method: str = "cubic", axis: int = -1, **kwargs
#      11 ):
#      12     """Approximates first derivatives using cubic spline interpolation.
#      13
#      14     Parameters
#    (...)     42
#      43     """
#
# File /scratch/miniconda3/envs/rod/lib/python3.12/site-packages/interpax/utils.py:42
#      38     if cond:
#      39         warnings.warn(msg, err)
# ---> 42 def asarray_inexact(x: Num[Arrayish, "..."]) -> Inexact[Array, "..."]:
#      43     """Convert to jax array with floating point dtype."""
#      44     x = jnp.asarray(x)
#
# File /scratch/miniconda3/envs/rod/lib/python3.12/site-packages/jaxtyping/_array_types.py:734, in _MetaAbstractDtype.__getitem__(***failed resolving arguments***)
#     732 del item
#     733 if get_origin(array_type) in _union_types:
# --> 734     out = [_make_array(x, dim_str, cls) for x in get_args(array_type)]
#     735     out = tuple(x for x in out if x is not _not_made)
#     736     if len(out) == 0:
#
# File /scratch/miniconda3/envs/rod/lib/python3.12/site-packages/jaxtyping/_array_types.py:659, in _make_array(x, dim_str, dtype)
#     658 def _make_array(x, dim_str, dtype):
# --> 659     out = _make_array_cached(x, dim_str, dtype.dtypes, dtype.__name__)
#     661     if type(out) is tuple:
#     662         array_type, name, dtypes, dims, index_variadic, dim_str = out
#
# File /scratch/miniconda3/envs/rod/lib/python3.12/site-packages/jaxtyping/_array_types.py:622, in _make_array_cached(array_type, dim_str, dtypes, name)
#     620     else:
#     621         return _not_made
# --> 622 if array_type is not Any and issubclass(array_type, AbstractArray):
#     623     if dtypes is _any_dtype:
#     624         dtypes = array_type.dtypes
#
# TypeError: issubclass() arg 1 must be a class

# %%
# ============================================================================
# Step 4B: Winkler clamp weights + physical clamp centres
# ============================================================================
# Clamp weights are evaluated in the BASE frame (same as Support.compute_weights).
# Lorentz / Biot–Savart live in beam_dolfinx.py at volume quadrature points.

import jax.numpy as jnp
from coil_fem.coupling import Support

curves_jax = Jstress.fem.base_curves_jax
sdofs = coil_support.support_dofs
support_weight = np.zeros(N, dtype=np.float64)

# Base-frame preimages for conductor nodes (for compute_weights).
y_base = np.zeros((N, 3), dtype=np.float64)
cond = owner_coil >= 0
if cond.any():
    Qs = Q_list[owner_sym[cond]]
    y_base[cond] = np.einsum('ni,nij->nj', X[cond], Qs)

t0 = time.time()
for i in range(n_base):
    sel = np.where(owner_coil == i)[0]
    if sel.size == 0:
        continue
    y_i = y_base[sel]
    # Clamp-only Winkler weights: call the base Support path with clamp
    # dofs so beam attachment weights stay zero on the fused mesh.
    w_g, _w_a = Support.compute_weights(
        self=support,
        coil_idx=i,
        surface_pts=jnp.asarray(y_i),
        curves_jax=curves_jax,
        dofs={'phis': sdofs['phis']},
    )
    support_weight[sel] = np.asarray(w_g)
    print(f'  coil {i}: {sel.size} nodes')

# Physical-frame clamp centres for dolfinx (analytic Winkler at facet quads).
phis_clamp = sdofs['phis']
r_clamp = float(coil_support._r_clamp)
eps_sigmoid = float(coil_support._sig_eps)
clamp_centers = []
for i in range(n_base):
    phi_i = np.asarray(phis_clamp[i], dtype=np.float64).ravel()
    c_base = np.asarray(
        Jstress.fem.base_curves_jax[i].gamma_eval(phi_i), dtype=np.float64,
    )
    for s in range(n_sym):
        clamp_centers.append(c_base @ Q_list[s].T)
clamp_centers = np.vstack(clamp_centers)
print(
    f'clamp_centers: {clamp_centers.shape[0]} '
    f'(n_base={n_base} x n_sym={n_sym} x n_clamp='
    f'{clamp_centers.shape[0] // (n_base * n_sym)}), '
    f'r_clamp={r_clamp:.4g}, eps_sigmoid={eps_sigmoid:.4g}'
)
print(f'clamp weights assembled in {time.time() - t0:.1f} s')
print(f'support_weight range: '
      f'[{support_weight.min():.3g}, {support_weight.max():.3g}]')

# %%
# ============================================================================
# Step 4C: round-trip check + body_force.npz
# ============================================================================

# Round-trip: rebuild x from (phi, u, v) for 1000 random conductor nodes
# and compare to the stored gmsh coordinate (loft chord sagitta ~ mm).
rng = np.random.default_rng(0)
cond_idx = np.where(owner_coil >= 0)[0]
n_check = min(1000, cond_idx.size)
pick = rng.choice(cond_idx, size=n_check, replace=False)

errs = np.empty(n_check)
for j, n in enumerate(pick):
    i = int(owner_coil[n])
    s = int(owner_sym[n])
    mesh = Jstress.fem.meshes[i]
    fc = mesh.framed_curve
    phi_n = float(phi_out[n])
    g = np.asarray(fc.curve.gamma_eval(np.array([phi_n])))[0]
    p = np.asarray(interpax.interp1d(
        np.array([phi_n]), phi_s, p_s[i], method='cubic2', period=1.0,
    ))[0]
    q = np.asarray(interpax.interp1d(
        np.array([phi_n]), phi_s, q_s[i], method='cubic2', period=1.0,
    ))[0]
    y = g + 0.5 * w1 * float(u_out[n]) * p + 0.5 * w2 * float(v_out[n]) * q
    x_rec = Q_list[s] @ y
    errs[j] = np.linalg.norm(x_rec - X[n])

print(f'round-trip max |x_rec - X| over {n_check} nodes: {errs.max()*1e3:.3f} mm')
assert errs.max() < 2e-3, (
    f'round-trip error {errs.max()*1e3:.3f} mm exceeds 2 mm loft-chord budget'
)
print(f'conductor fraction: {100 * cond_idx.size / N:.1f}%')

g_vec_save = np.asarray(
    gravity_options.get('g_vec', (0.0, 0.0, 0.0)), dtype=np.float64,
)
np.savez(
    'body_force.npz',
    points=X,
    node_tags=node_tags,
    support_weight=support_weight,
    owner_coil=owner_coil,
    owner_sym=owner_sym,
    phi=phi_out,
    u=u_out,
    v=v_out,
    rho=np.float64(material_options['density']),
    g_vec=g_vec_save,
    k_clamp=np.float64(support.k_clamp),
    E=np.float64(material_options['E']),
    nu=np.float64(material_options['nu']),
    clamp_centers=clamp_centers,
    r_clamp=np.float64(r_clamp),
    eps_sigmoid=np.float64(eps_sigmoid),
)
print('wrote body_force.npz (no f_vol / B_*; force computed in beam_dolfinx)')

# %%
# ============================================================================
# Step 4D: VTU sanity dump (classification + clamp weights)
# ============================================================================
# Connectivity from the live gmsh session. gmsh tet10 edge order
# (01)(12)(02)(03)(23)(13) -> VTK (01)(12)(02)(03)(13)(23).

import meshio

etags, enodes = gmsh.model.mesh.getElementsByType(11)  # 11 = TET10

inv = np.zeros(int(node_tags.max()) + 1, dtype=np.int64)
inv[node_tags] = np.arange(node_tags.size)
cells = inv[np.asarray(enodes, dtype=np.int64).reshape(-1, 10)][:, [0, 1, 2, 3, 4, 5, 6, 7, 9, 8]]

meshio.Mesh(
    points=X,
    cells=[('tetra10', cells)],
    point_data={
        'w_clamp': support_weight,
        'k_clamp_Npm3': support_weight * float(support.k_clamp),
        'owner_coil': owner_coil.astype(np.int32),   # -1 = beam/steel
        'owner_sym': owner_sym.astype(np.int32),
    },
).write('full_body_fields.vtu')
print(f'wrote full_body_fields.vtu ({cells.shape[0]} tet10 cells, {N} nodes)')

# %% [markdown]
# ### Step 5: import into dolfinx
# `dolfinx.io.gmshio.model_to_mesh` converts the live gmsh model directly (the physical group added in Step 3 is required — dolfinx only imports tagged cells). If dolfinx is installed in a different environment than gmsh/coil-fem, use `gmshio.read_from_msh('device.msh', ...)` there instead.

# %%
# ============================================================================
# Step 5: import into dolfinx
# ============================================================================
# Reads the mesh straight from the live gmsh model (no file round-trip).
# If dolfinx lives in a different environment, run there instead:
#     domain, ct, ft = gmshio.read_from_msh('device.msh', MPI.COMM_WORLD,
#                                           rank=0, gdim=3)
from mpi4py import MPI
from dolfinx.io import gmshio

domain, cell_tags, facet_tags = gmshio.model_to_mesh(
    gmsh.model, MPI.COMM_WORLD, rank=0, gdim=3,
)
gmsh.finalize()

tdim = domain.topology.dim
domain.topology.create_connectivity(tdim, tdim)
print('cells:', domain.topology.index_map(tdim).size_global)
print('nodes:', domain.geometry.x.shape[0])
